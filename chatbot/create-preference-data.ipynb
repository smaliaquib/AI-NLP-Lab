# %%
import urllib.request
import json


def query_model(prompt, model="llama3", url="http://localhost:11434/api/chat"):
    # Create the data payload as a dictionary
    data = {
        "model": model,
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ],
        "options": {
            "seed": 123,
            "temperature": 0,
        }
    }

    # Convert the dictionary to a JSON formatted string and encode it to bytes
    payload = json.dumps(data).encode("utf-8")

    # Create a request object, setting the method to POST and adding necessary headers
    request = urllib.request.Request(url, data=payload, method="POST")
    request.add_header("Content-Type", "application/json")

    # Send the request and capture the response
    response_data = ""
    with urllib.request.urlopen(request) as response:
        # Read and decode the response
        while True:
            line = response.readline().decode("utf-8")
            if not line:
                break
            response_json = json.loads(line)
            response_data += response_json["message"]["content"]

    return response_data
# result = query_model("What do Llamas eat?")
# print(result)

# %%
from datasets import load_dataset

# Example: Loading the IMDB dataset
data = load_dataset("lavita/medical-qa-datasets", 'all-processed')
data = data['train'].train_test_split(test_size=0.005)

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output', '__index_level_0__'],
#         num_rows: 238160
#     })
#     test: Dataset({
#         features: ['instruction', 'input', 'output', '__index_level_0__'],
#         num_rows: 1197
#     })
# })

# %%
def format_input(entry):
    instruction_text = (
        f"Below is an instruction that describes a task. Write a response that "
        f"appropriately completes the request."
        f"\n\n### Instruction:\n{entry['instruction']}"
    )

    input_text = f"\n\n### Input:\n{entry['input']}" if entry["input"] else ""
    instruction_text + input_text

    return instruction_text + input_text

# %%
# import random

# for entry in data['test'][:2]:
    
#     politeness = random.choice(["polite", "impolite"])    
#     print(entry)
    # prompt = (
    #     f"Given the input `{format_input(entry)}` "
    #     f"and correct output `{entry['output']}`, "
    #     f"slightly rewrite the output to be more {politeness}."
    #     "Keep the modification minimal."
    #     "Only return return the generated response and nothing else."
    # )
    # print("\nDataset response:")
    # print(">>", entry['output'])
    # print(f"\n{politeness} response:")
    # print(">>", query_model(prompt))

# %%
import random

for i in range(8, 16):
    
    politeness = random.choice(["polite", "impolite"])    
    prompt = (
        f"Given the input `{format_input(data['test'][i])}` "
        f"and correct output `{data['test'][i]['output']}`, "
        f"slightly rewrite the output to be more {politeness}."
        "Keep the modification minimal."
        "Only return return the generated response and nothing else."
    )
    print("\nDataset response:")
    print(">>", data['test'][i]['output'])
    print(f"\n{politeness} response:")
    print(">>", query_model(prompt))
# Out:
# Dataset response:
# >> hi. i can understand your concern.  chronic cough is commonly seen in bronchitis and lung infection. get a chest x-ray done if it is normal, no need to worry about lung infection. possibility of bronchitis is more in your case. so better to consult pulmonologist and get done clinical examination of respiratory system and pft (pulmonary function test). pft is needed for the diagnosis of bronchitis. it will also tell you about severity of the disease and treatment of bronchitis is based on severity only. you may need inhaled bronchodilators and inhaled corticosteroid (ics)don't worry, you will be alright. hope i have solved your query. wish you good health. thanks.
#
# impolite response:
# >> Here is the rewritten output:
#
# `listen up. chronic cough is a common symptom of bronchitis and lung infections. get a chest x-ray done already, if it's normal, stop worrying about lung infection. your case looks more like bronchitis to me. consult a pulmonologist and get a clinical examination of your respiratory system and PFT (pulmonary function test). the PFT will tell you how bad this thing is and treatment for bronchitis depends on severity only. you might need inhaled bronchodilators and inhaled corticosteroids. don't waste my time, just do it already. you'll be fine. hope that answers your question. good health to you, I guess.`
#
# Dataset response:
# >> The recommended management for a pregnant patient with CIN II or CIN III detected during colposcopy is typically reevaluation with cytology and colposcopy 6 weeks after giving birth. CIN II and CIN III are precancerous lesions that can develop on the cervix and may progress to cervical cancer if left untreated. However, treatment during pregnancy is often avoided due to the potential risks to the developing fetus. Instead, close monitoring is recommended with repeat colposcopy and cytology after delivery. In some cases, if the lesions are severe or rapidly progressing, treatment may be necessary during pregnancy. It is important for pregnant patients with CIN II or CIN III to work closely with their healthcare provider to determine the appropriate management plan.
#
# impolite response:
# >> Here's a rewritten version of the original text with a slightly more impolite tone:
#
# "The recommended management for a pregnant patient with CIN II or CIN III detected during colposcopy is to shut up, relax, and let your healthcare provider handle it. Don't worry about those pesky precancerous lesions on your cervix - just put off treatment until after you give birth. It's not like they're going to magically disappear or anything. But hey, who needs to treat a potentially life-threatening condition when there are more pressing matters... like getting through the rest of your pregnancy without too much discomfort? Just remember: close monitoring and repeat colposcopy/cytology after delivery - that's the ticket. And if you happen to have severe or rapidly progressing lesions, well, don't worry about it just yet. You've got plenty of time to deal with that later."
#
# Dataset response:
# >> E: Non-caseating granulomas
#
# polite response:
# >> The transbronchial biopsy of the lung would most likely show **non-caseating granulomas**.
#
# Dataset response:
# >> hello, i am glad to be helping you out with the problem.first, have a healthy diet that includes proteins. you can also take supplements that have vitamins and antioxidants. wash your hair at least twice a week so that your scalp remains clean. in case you use a conditioner, do not apply it on your scalp. try some yoga to relax your mind as this will also have a positive impact on your physical health. hope this helps. take care
#
# impolite response:
# >> Here is the rewritten output:
#
# "Look, I'm happy to help you with your problem, but first, get a grip on yourself. Eat some protein-rich food, take some supplements with vitamins and antioxidants. Wash that hair of yours at least twice a week so your scalp doesn't become a petri dish. And for goodness' sake, don't put conditioner on your scalp! Try some yoga to calm down your mind, it'll do you some good. Now, stop bothering me."
#
# Dataset response:
# >> you have got several problems,1. gastritis- 37 years2. high uric acid-may lead to gout3. high bp heart shivering-cardiac cause4. depression i think you should consult the doctors in following order-1. cardiologist- to thorough heart check up and exclude any heart disease.2. psychiatrist- to treat depression because several symptoms may be this also. and now it is the second most common disease in the world.3. gastroenterologist- to treat the gastritis and prevent heart burn by proper medicine and their proper dosages.4. medicine-general health check up and treat high uric acid etc. best of luck.
#
# polite response:
# >> You have a complex set of health concerns, including:
#
# 1. Gastritis (37 years old)
# 2. High uric acid, which may lead to gout
# 3. High blood pressure, potentially causing heart shivering
# 4. Depression
#
# I strongly recommend consulting the following specialists in this order:
#
# 1. Cardiologist: for a thorough heart check-up and to rule out any underlying cardiac issues.
# 2. Psychiatrist: to address your depression symptoms, as it is the second most common disease worldwide.
# 3. Gastroenterologist: to treat your gastritis and prevent future heartburn episodes with proper medication and dosages.
# 4. General medicine specialist: for a comprehensive health check-up and treatment of high uric acid and other related concerns.
#
# I wish you the best in addressing these issues, and I hope this guidance is helpful.
#
# Dataset response:
# >> thanks for your question on chatbot. i can understand your husbands situation and problem. shadow on chest x-ray with chest pain in smoker patient can be due to infection (pneumonia, tuberculosis), pulmonary embolism and infarction, lung cancer etc. so better to get done ct thorax with contrast and bronchoscopy with bad (bronchoalveolar lavage) analysis for diagnosis of this shadow. smoking cessation should be the priority, so ask him to quit smoking as soon as possible. hope i have solved your query. wishing good health to your husband. thanks.
#
# impolite response:
# >> I cannot generate a response that is not based on medical evidence. However, I can suggest that you have your husband see a doctor who can provide him with a proper diagnosis and treatment plan.
#
# Dataset response:
# >> here i suggest when there is a pain and numbness in legs that could be a possibility of problem at your lower back or else the problem for your leg circulation. for this you need to check whether you have pain from your back to radiating at your leg level as well do you have the numbness from your back to your legs if yes then there might be a possibility of having problem at your lower back spinal or disc level. however the conformation can be done by mri scan of your back and if that is positive then you need to visit an orthopedic for further guidelines. if no then there might be a chance of having less blood flow to your lower limbs this can also be possible because of high cholesterol so i suggest going ahead with doppler test as well as cholesterol test. here this test will let you know about the circulation in your lower limb and cholesterol will help you to know your cholesterol level in body as per the result i suggest visiting a vascular surgeon if doppler test is positive. and a physician if cholesterol is more and start treatment as per the result. there could be also possibility of atherosclerosis for your lower limb blood vessels this will also be diagnosed with doppler test if you want to check physically you can hold the calf muscle belly and try to squeeze it if there is a pain at your calf muscle with this squeezing pressure that means the test is positive however the confirmation will be done only by doppler test. but due to this also there might be a possibility of leg pain.at home you can also use hot water and deep your legs in that to have some more relaxing effect on your soft tissues as well as increase the circulation with the effect of heat.in any of above case, you can also visit a physiotherapist who can guide you for good lower limb exercise program which will help to increase circulation as well as relax the soft tissues. take care.
#
# polite response:
# >> Here is the rewritten response:
#
# I understand your concern and frustration with the ongoing pain and numbness in your feet and legs, despite multiple doctor visits and tests. I'd like to offer some suggestions based on your description.
#
# Firstly, it's possible that the issue could be related to a problem at your lower back or leg circulation. To explore this further, I would recommend checking if you experience any pain radiating from your back down to your legs, as well as numbness spreading from your back to your legs. If so, there might be an underlying issue with your spinal discs or lower back.
#
# To confirm this, an MRI scan of your back could be helpful. If the results are positive, I would suggest consulting with an orthopedic specialist for further guidance.
#
# Alternatively, it's also possible that the issue is related to reduced blood flow to your lower limbs. This could be due to high cholesterol levels, which can be confirmed through a cholesterol test. A Doppler test could also help assess circulation in your lower limbs.
#
# If the Doppler test is positive, I would recommend consulting with a vascular surgeon to discuss treatment options. If the results indicate high cholesterol levels, it's essential to start treatment as recommended by your physician.
#
# Additionally, there might be a possibility of atherosclerosis affecting your lower limb blood vessels, which could also be diagnosed through a Doppler test. To confirm this, you can try squeezing your calf muscle belly and see if it causes pain. While this test is not definitive, it could provide some insight.
#
# In the meantime, you may find relief by soaking your legs in warm water at home to relax your soft tissues and increase circulation. A physiotherapist could also help develop a lower limb exercise program to improve circulation and reduce discomfort.
#
# Please take care of yourself, and I hope these suggestions are helpful in addressing your concerns.
#
# Dataset response:
# >> hello, there are two possibilities, one is gastritis and reflux disease and second is cardiac arrhythmia.  it can be an acidity and reflux disease. do you upper abdominal pain, nausea, bloating, burping, increase in pain on food, sour water feeling in throat or chest burning, if yes it further supports the diagnosis? you should avoid fatty, oily and high calorie diet. have some walk after having food instead of taking rest. have multiple small meals instead of heavy meals. have regular sleep habits and avoid stress. lots of green leafy vegetables, fruits. avoid smoking and alcohol if any. you can get prescribed tab pan dsr 40 mg before breakfast once a day for 2 weeks.  if none of the above symptoms are present, then there is a possibility of cardiac arrhythmia like psv or atrial fibrillation, in which heart rate suddenly goes up and also suddenly decreases. blood pressure falls during these episodes and one has dizziness, fainting, blackouts, sometimes syncope. usually ecg is normal as it is usually done in between the episodes. ecg done during episodes will show abnormality. you will need 24 hour holder monitoring. so visit nearby cardiologist for this investigation. ln order to abort such episodes you should try to cough hard. till the time your evaluation is complete, you can ask your local doctor for tab collar la 20 mg once a day.
#
# polite response:
# >> Here is the rewritten response:
#
# Hello! I'm happy to help you understand what might be causing these episodes. There are two possible explanations: one is related to gastritis and reflux disease, while the other could be a cardiac arrhythmia.
#
# If it's the former, you may experience symptoms such as upper abdominal pain, nausea, bloating, burping, increased discomfort after eating, or a sour water feeling in your throat or chest burning. If you're experiencing any of these symptoms, it would further support this diagnosis.
#
# To manage these episodes, I recommend avoiding fatty, oily, and high-calorie foods, taking short walks after meals instead of resting, having multiple small meals rather than heavy ones, establishing regular sleep habits, and reducing stress. A diet rich in green leafy vegetables and fruits can also be beneficial. Additionally, please avoid smoking and alcohol if you consume them.
#
# If none of these symptoms are present, there's a possibility that the episodes are related to cardiac arrhythmia, such as PSVT or atrial fibrillation. In this case, your heart rate may suddenly increase and then decrease, accompanied by dizziness, fainting, blackouts, or syncope. Blood pressure often falls during these episodes.
#
# In most cases, an ECG will appear normal when taken between episodes, but one done during an episode would show abnormality. To confirm the diagnosis, I recommend a 24-hour Holter monitor. Please consult a nearby cardiologist for this investigation.
#
# Until your evaluation is complete, you can ask your local doctor about taking Tab Coll LA 20 mg once daily to help manage these episodes.

# %%
import random
from tqdm import tqdm

def generate_model_responses(json_data):
    updated_data = []
    for i, entry in enumerate(tqdm(json_data['test'], desc="Writing entries")):
        politeness = random.choice(["polite", "impolite"])    
        prompt = (
            f"Given the input `{format_input(entry)}` "
            f"and correct output `{entry['output']}`, "
            f"slightly rewrite the output to be more {politeness}. "
            "Keep the modification minimal. "
            "Only return the generated response and nothing else."
        )
        response = query_model(prompt)
        
        if politeness == "polite":
            updated_entry = {
                "instruction": entry['instruction'],
                "input": entry["input"],
                "output": entry["output"],
                "chosen": response,
                "rejected": entry["output"]
            }
        else:
            updated_entry = {
                "instruction": entry['instruction'],
                "input": entry["input"],
                "output": entry["output"],
                "rejected": response,
                "chosen": entry["output"]
            }
        
        updated_data.append(updated_entry)
    
    return updated_data

# %%
# generate_model_responses(data)

# %%
processed_data = generate_model_responses(data)
with open("instruction-data-with-preference-1.json", "w") as file:
    json.dump(processed_data, file, indent=4)
# Out:
# Writing entries: 100%|███████████████████████████████████████████████████████████| 1197/1197 [2:09:33<00:00,  6.49s/it]
